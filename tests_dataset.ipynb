# %%
import datetime as dt
import time
#import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#import scipy as sp

import pyxu.abc as pxa
import pyxu.operator as pxop
import pyxu.opt.stop as pxos
#from pyxu.opt.solver.pgd import PGD

import pfw_hawkes as pyfwl
from hawkes_likelihood import HawkesLikelihood
import utils as ut

seed = 1  # None  # for reproducibility
if seed is None:
    seed = np.random.randint(0, 1000)
print(f"Seed: {seed}")
# Out:
# Seed: 1

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib qt

# %% [markdown]
# ### Import data

# %%
path = "turtle_data/events0.csv"
beta = 5
hpL = HawkesLikelihood(path=path, beta=beta)
# Out:
# Computing A^1 out of 200, k1=75
# Computing A^2 out of 200, k2=288
# Computing A^3 out of 200, k3=694
# Computing A^4 out of 200, k4=29
# Computing A^5 out of 200, k5=176
# Computing A^6 out of 200, k6=209
# Computing A^7 out of 200, k7=83
# Computing A^8 out of 200, k8=301
# Computing A^9 out of 200, k9=1727
# Computing A^10 out of 200, k10=556
# Computing A^11 out of 200, k11=141
# Computing A^12 out of 200, k12=1114
# Computing A^13 out of 200, k13=342
# Computing A^14 out of 200, k14=390
# Computing A^15 out of 200, k15=499
# Computing A^16 out of 200, k16=616
# Computing A^17 out of 200, k17=543
# Computing A^18 out of 200, k18=386
# Computing A^19 out of 200, k19=710
# Computing A^20 out of 200, k20=210
# Computing A^21 out of 200, k21=218
# Computing A^22 out of 200, k22=211
# Computing A^23 out of 200, k23=485
# Computing A^24 out of 200, k24=321
# Computing A^25 out of 200, k25=305
# Computing A^26 out of 200, k26=1088
# Computing A^27 out of 200, k27=678
# Computing A^28 out of 200, k28=467
# Computing A^29 out of 200, k29=140
# Computing A^30 out of 200, k30=604
# Computing A^31 out of 200, k31=79
# Computing A^32 out of 200, k32=179
# Computing A^33 out of 200, k33=201
# Computing A^34 out of 200, k34=166
# Computing A^35 out of 200, k35=595
# Computing A^36 out of 200, k36=905
# Computing A^37 out of 200, k37=858
# Computing A^38 out of 200, k38=128
# Computing A^39 out of 200, k39=1178
# Computing A^40 out of 200, k40=334
# Computing A^41 out of 200, k41=331
# Computing A^42 out of 200, k42=227
# Computing A^43 out of 200, k43=427
# Computing A^44 out of 200, k44=474
# Computing A^45 out of 200, k45=137
# Computing A^46 out of 200, k46=1041
# Computing A^47 out of 200, k47=257
# Computing A^48 out of 200, k48=468
# Computing A^49 out of 200, k49=415
# Computing A^50 out of 200, k50=852
# Computing A^51 out of 200, k51=663
# Computing A^52 out of 200, k52=611
# Computing A^53 out of 200, k53=445
# Computing A^54 out of 200, k54=208
# Computing A^55 out of 200, k55=452
# Computing A^56 out of 200, k56=91
# Computing A^57 out of 200, k57=382
# Computing A^58 out of 200, k58=1029
# Computing A^59 out of 200, k59=505
# Computing A^60 out of 200, k60=1308
# Computing A^61 out of 200, k61=473
# Computing A^62 out of 200, k62=285
# Computing A^63 out of 200, k63=1523
# Computing A^64 out of 200, k64=205
# Computing A^65 out of 200, k65=183
# Computing A^66 out of 200, k66=30
# Computing A^67 out of 200, k67=356
# Computing A^68 out of 200, k68=1545
# Computing A^69 out of 200, k69=139
# Computing A^70 out of 200, k70=334
# Computing A^71 out of 200, k71=200
# Computing A^72 out of 200, k72=62
# Computing A^73 out of 200, k73=24
# Computing A^74 out of 200, k74=86
# Computing A^75 out of 200, k75=886
# Computing A^76 out of 200, k76=248
# Computing A^77 out of 200, k77=1103
# Computing A^78 out of 200, k78=354
# Computing A^79 out of 200, k79=678
# Computing A^80 out of 200, k80=477
# Computing A^81 out of 200, k81=196
# Computing A^82 out of 200, k82=157
# Computing A^83 out of 200, k83=473
# Computing A^84 out of 200, k84=108
# Computing A^85 out of 200, k85=776
# Computing A^86 out of 200, k86=388
# Computing A^87 out of 200, k87=1186
# Computing A^88 out of 200, k88=126
# Computing A^89 out of 200, k89=11
# Computing A^90 out of 200, k90=11
# Computing A^91 out of 200, k91=1075
# Computing A^92 out of 200, k92=16
# Computing A^93 out of 200, k93=923
# Computing A^94 out of 200, k94=93
# Computing A^95 out of 200, k95=326
# Computing A^96 out of 200, k96=567
# Computing A^97 out of 200, k97=571
# Computing A^98 out of 200, k98=200
# Computing A^99 out of 200, k99=59
# Computing A^100 out of 200, k100=208
# Computing A^101 out of 200, k101=263
# Computing A^102 out of 200, k102=40
# Computing A^103 out of 200, k103=44
# Computing A^104 out of 200, k104=699
# Computing A^105 out of 200, k105=385
# Computing A^106 out of 200, k106=98
# Computing A^107 out of 200, k107=3984
# Computing A^108 out of 200, k108=13
# Computing A^109 out of 200, k109=315
# Computing A^110 out of 200, k110=286
# Computing A^111 out of 200, k111=219
# Computing A^112 out of 200, k112=41
# Computing A^113 out of 200, k113=478
# Computing A^114 out of 200, k114=380
# Computing A^115 out of 200, k115=1106
# Computing A^116 out of 200, k116=280
# Computing A^117 out of 200, k117=91
# Computing A^118 out of 200, k118=513
# Computing A^119 out of 200, k119=1402
# Computing A^120 out of 200, k120=101
# Computing A^121 out of 200, k121=11
# Computing A^122 out of 200, k122=4
# Computing A^123 out of 200, k123=39
# Computing A^124 out of 200, k124=70
# Computing A^125 out of 200, k125=597
# Computing A^126 out of 200, k126=58
# Computing A^127 out of 200, k127=951
# Computing A^128 out of 200, k128=1508
# Computing A^129 out of 200, k129=917
# Computing A^130 out of 200, k130=239
# Computing A^131 out of 200, k131=754
# Computing A^132 out of 200, k132=322
# Computing A^133 out of 200, k133=452
# Computing A^134 out of 200, k134=110
# Computing A^135 out of 200, k135=36
# Computing A^136 out of 200, k136=1222
# Computing A^137 out of 200, k137=94
# Computing A^138 out of 200, k138=42
# Computing A^139 out of 200, k139=3
# Computing A^140 out of 200, k140=682
# Computing A^141 out of 200, k141=194
# Computing A^142 out of 200, k142=3954
# Computing A^143 out of 200, k143=402
# Computing A^144 out of 200, k144=192
# Computing A^145 out of 200, k145=590
# Computing A^146 out of 200, k146=328
# Computing A^147 out of 200, k147=249
# Computing A^148 out of 200, k148=567
# Computing A^149 out of 200, k149=201
# Computing A^150 out of 200, k150=479
# Computing A^151 out of 200, k151=174
# Computing A^152 out of 200, k152=224
# Computing A^153 out of 200, k153=782
# Computing A^154 out of 200, k154=3835
# Computing A^155 out of 200, k155=292
# Computing A^156 out of 200, k156=583
# Computing A^157 out of 200, k157=264
# Computing A^158 out of 200, k158=2581
# Computing A^159 out of 200, k159=283
# Computing A^160 out of 200, k160=571
# Computing A^161 out of 200, k161=1736
# Computing A^162 out of 200, k162=712
# Computing A^163 out of 200, k163=164
# Computing A^164 out of 200, k164=152
# Computing A^165 out of 200, k165=143
# Computing A^166 out of 200, k166=495
# Computing A^167 out of 200, k167=122
# Computing A^168 out of 200, k168=141
# Computing A^169 out of 200, k169=692
# Computing A^170 out of 200, k170=145
# Computing A^171 out of 200, k171=163
# Computing A^172 out of 200, k172=36
# Computing A^173 out of 200, k173=22
# Computing A^174 out of 200, k174=13
# Computing A^175 out of 200, k175=199
# Computing A^176 out of 200, k176=54
# Computing A^177 out of 200, k177=128
# Computing A^178 out of 200, k178=399
# Computing A^179 out of 200, k179=88
# Computing A^180 out of 200, k180=660
# Computing A^181 out of 200, k181=69
# Computing A^182 out of 200, k182=40
# Computing A^183 out of 200, k183=139
# Computing A^184 out of 200, k184=1034
# Computing A^185 out of 200, k185=173
# Computing A^186 out of 200, k186=215
# Computing A^187 out of 200, k187=685
# Computing A^188 out of 200, k188=445
# Computing A^189 out of 200, k189=535
# Computing A^190 out of 200, k190=131
# Computing A^191 out of 200, k191=149
# Computing A^192 out of 200, k192=218
# Computing A^193 out of 200, k193=40
# Computing A^194 out of 200, k194=86
# Computing A^195 out of 200, k195=180
# Computing A^196 out of 200, k196=57
# Computing A^197 out of 200, k197=154
# Computing A^198 out of 200, k198=129
# Computing A^199 out of 200, k199=55
# Computing A^200 out of 200, k200=327

# %%
hpL1 = HawkesLikelihood(path="turtle_data/events1.csv", beta=beta)
# Out:
# Computing A^1 out of 64, k1=293
# Computing A^2 out of 64, k2=1221
# Computing A^3 out of 64, k3=222
# Computing A^4 out of 64, k4=16
# Computing A^5 out of 64, k5=9
# Computing A^6 out of 64, k6=10
# Computing A^7 out of 64, k7=749
# Computing A^8 out of 64, k8=705
# Computing A^9 out of 64, k9=784
# Computing A^10 out of 64, k10=566
# Computing A^11 out of 64, k11=6176
# Computing A^12 out of 64, k12=1625
# Computing A^13 out of 64, k13=3741
# Computing A^14 out of 64, k14=1463
# Computing A^15 out of 64, k15=10815
# Computing A^16 out of 64, k16=934
# Computing A^17 out of 64, k17=5105
# Computing A^18 out of 64, k18=3340
# Computing A^19 out of 64, k19=644
# Computing A^20 out of 64, k20=317
# Computing A^21 out of 64, k21=5061
# Computing A^22 out of 64, k22=81
# Computing A^23 out of 64, k23=8
# Computing A^24 out of 64, k24=2925
# Computing A^25 out of 64, k25=890
# Computing A^26 out of 64, k26=11
# Computing A^27 out of 64, k27=149
# Computing A^28 out of 64, k28=668
# Computing A^29 out of 64, k29=4514
# Computing A^30 out of 64, k30=646
# Computing A^31 out of 64, k31=182
# Computing A^32 out of 64, k32=2590
# Computing A^33 out of 64, k33=479
# Computing A^34 out of 64, k34=897
# Computing A^35 out of 64, k35=735
# Computing A^36 out of 64, k36=1126
# Computing A^37 out of 64, k37=207
# Computing A^38 out of 64, k38=225
# Computing A^39 out of 64, k39=829
# Computing A^40 out of 64, k40=389
# Computing A^41 out of 64, k41=1542
# Computing A^42 out of 64, k42=1536
# Computing A^43 out of 64, k43=66
# Computing A^44 out of 64, k44=23
# Computing A^45 out of 64, k45=90
# Computing A^46 out of 64, k46=393
# Computing A^47 out of 64, k47=104
# Computing A^48 out of 64, k48=254
# Computing A^49 out of 64, k49=305
# Computing A^50 out of 64, k50=1150
# Computing A^51 out of 64, k51=90
# Computing A^52 out of 64, k52=242
# Computing A^53 out of 64, k53=82
# Computing A^54 out of 64, k54=329
# Computing A^55 out of 64, k55=815
# Computing A^56 out of 64, k56=1171
# Computing A^57 out of 64, k57=239
# Computing A^58 out of 64, k58=326
# Computing A^59 out of 64, k59=4682
# Computing A^60 out of 64, k60=773
# Computing A^61 out of 64, k61=1354
# Computing A^62 out of 64, k62=253
# Computing A^63 out of 64, k63=644
# Computing A^64 out of 64, k64=167

# %%
hpL2 = HawkesLikelihood(path="turtle_data/events2.csv", beta=beta)
# Out:
# Computing A^1 out of 214, k1=86
# Computing A^2 out of 214, k2=149
# Computing A^3 out of 214, k3=298
# Computing A^4 out of 214, k4=4433
# Computing A^5 out of 214, k5=251
# Computing A^6 out of 214, k6=157
# Computing A^7 out of 214, k7=20
# Computing A^8 out of 214, k8=285
# Computing A^9 out of 214, k9=205
# Computing A^10 out of 214, k10=1505
# Computing A^11 out of 214, k11=662
# Computing A^12 out of 214, k12=74
# Computing A^13 out of 214, k13=378
# Computing A^14 out of 214, k14=283
# Computing A^15 out of 214, k15=102
# Computing A^16 out of 214, k16=118
# Computing A^17 out of 214, k17=512
# Computing A^18 out of 214, k18=220
# Computing A^19 out of 214, k19=155
# Computing A^20 out of 214, k20=1222
# Computing A^21 out of 214, k21=2578
# Computing A^22 out of 214, k22=1037
# Computing A^23 out of 214, k23=1709
# Computing A^24 out of 214, k24=475
# Computing A^25 out of 214, k25=583
# Computing A^26 out of 214, k26=468
# Computing A^27 out of 214, k27=1035
# Computing A^28 out of 214, k28=37
# Computing A^29 out of 214, k29=379
# Computing A^30 out of 214, k30=71
# Computing A^31 out of 214, k31=4867
# Computing A^32 out of 214, k32=141
# Computing A^33 out of 214, k33=206
# Computing A^34 out of 214, k34=1154
# Computing A^35 out of 214, k35=1718
# Computing A^36 out of 214, k36=1619
# Computing A^37 out of 214, k37=495
# Computing A^38 out of 214, k38=56
# Computing A^39 out of 214, k39=1253
# Computing A^40 out of 214, k40=218
# Computing A^41 out of 214, k41=64
# Computing A^42 out of 214, k42=29
# Computing A^43 out of 214, k43=742
# Computing A^44 out of 214, k44=28
# Computing A^45 out of 214, k45=42
# Computing A^46 out of 214, k46=1601
# Computing A^47 out of 214, k47=1790
# Computing A^48 out of 214, k48=294
# Computing A^49 out of 214, k49=60
# Computing A^50 out of 214, k50=772
# Computing A^51 out of 214, k51=1157
# Computing A^52 out of 214, k52=629
# Computing A^53 out of 214, k53=78
# Computing A^54 out of 214, k54=238
# Computing A^55 out of 214, k55=166
# Computing A^56 out of 214, k56=151
# Computing A^57 out of 214, k57=153
# Computing A^58 out of 214, k58=28
# Computing A^59 out of 214, k59=265
# Computing A^60 out of 214, k60=534
# Computing A^61 out of 214, k61=344
# Computing A^62 out of 214, k62=278
# Computing A^63 out of 214, k63=132
# Computing A^64 out of 214, k64=276
# Computing A^65 out of 214, k65=411
# Computing A^66 out of 214, k66=653
# Computing A^67 out of 214, k67=220
# Computing A^68 out of 214, k68=826
# Computing A^69 out of 214, k69=653
# Computing A^70 out of 214, k70=246
# Computing A^71 out of 214, k71=199
# Computing A^72 out of 214, k72=240
# Computing A^73 out of 214, k73=1341
# Computing A^74 out of 214, k74=88
# Computing A^75 out of 214, k75=217
# Computing A^76 out of 214, k76=254
# Computing A^77 out of 214, k77=149
# Computing A^78 out of 214, k78=130
# Computing A^79 out of 214, k79=1137
# Computing A^80 out of 214, k80=475
# Computing A^81 out of 214, k81=374
# Computing A^82 out of 214, k82=141
# Computing A^83 out of 214, k83=117
# Computing A^84 out of 214, k84=140
# Computing A^85 out of 214, k85=305
# Computing A^86 out of 214, k86=249
# Computing A^87 out of 214, k87=122
# Computing A^88 out of 214, k88=504
# Computing A^89 out of 214, k89=47
# Computing A^90 out of 214, k90=168
# Computing A^91 out of 214, k91=249
# Computing A^92 out of 214, k92=225
# Computing A^93 out of 214, k93=2326
# Computing A^94 out of 214, k94=548
# Computing A^95 out of 214, k95=521
# Computing A^96 out of 214, k96=229
# Computing A^97 out of 214, k97=129
# Computing A^98 out of 214, k98=232
# Computing A^99 out of 214, k99=1762
# Computing A^100 out of 214, k100=461
# Computing A^101 out of 214, k101=83
# Computing A^102 out of 214, k102=2362
# Computing A^103 out of 214, k103=249
# Computing A^104 out of 214, k104=1035
# Computing A^105 out of 214, k105=267
# Computing A^106 out of 214, k106=319
# Computing A^107 out of 214, k107=96
# Computing A^108 out of 214, k108=170
# Computing A^109 out of 214, k109=629
# Computing A^110 out of 214, k110=50
# Computing A^111 out of 214, k111=292
# Computing A^112 out of 214, k112=542
# Computing A^113 out of 214, k113=604
# Computing A^114 out of 214, k114=1165
# Computing A^115 out of 214, k115=163
# Computing A^116 out of 214, k116=283
# Computing A^117 out of 214, k117=734
# Computing A^118 out of 214, k118=496
# Computing A^119 out of 214, k119=1160
# Computing A^120 out of 214, k120=667
# Computing A^121 out of 214, k121=292
# Computing A^122 out of 214, k122=226
# Computing A^123 out of 214, k123=863
# Computing A^124 out of 214, k124=352
# Computing A^125 out of 214, k125=240
# Computing A^126 out of 214, k126=23
# Computing A^127 out of 214, k127=428
# Computing A^128 out of 214, k128=278
# Computing A^129 out of 214, k129=514
# Computing A^130 out of 214, k130=226
# Computing A^131 out of 214, k131=756
# Computing A^132 out of 214, k132=1693
# Computing A^133 out of 214, k133=453
# Computing A^134 out of 214, k134=62
# Computing A^135 out of 214, k135=33
# Computing A^136 out of 214, k136=30
# Computing A^137 out of 214, k137=309
# Computing A^138 out of 214, k138=182
# Computing A^139 out of 214, k139=48
# Computing A^140 out of 214, k140=117
# Computing A^141 out of 214, k141=128
# Computing A^142 out of 214, k142=73
# Computing A^143 out of 214, k143=99
# Computing A^144 out of 214, k144=284
# Computing A^145 out of 214, k145=50
# Computing A^146 out of 214, k146=144
# Computing A^147 out of 214, k147=81
# Computing A^148 out of 214, k148=64
# Computing A^149 out of 214, k149=244
# Computing A^150 out of 214, k150=29
# Computing A^151 out of 214, k151=190
# Computing A^152 out of 214, k152=603
# Computing A^153 out of 214, k153=45
# Computing A^154 out of 214, k154=106
# Computing A^155 out of 214, k155=819
# Computing A^156 out of 214, k156=204
# Computing A^157 out of 214, k157=349
# Computing A^158 out of 214, k158=477
# Computing A^159 out of 214, k159=424
# Computing A^160 out of 214, k160=71
# Computing A^161 out of 214, k161=439
# Computing A^162 out of 214, k162=193
# Computing A^163 out of 214, k163=175
# Computing A^164 out of 214, k164=75
# Computing A^165 out of 214, k165=338
# Computing A^166 out of 214, k166=511
# Computing A^167 out of 214, k167=163
# Computing A^168 out of 214, k168=710
# Computing A^169 out of 214, k169=718
# Computing A^170 out of 214, k170=2054
# Computing A^171 out of 214, k171=5571
# Computing A^172 out of 214, k172=1269
# Computing A^173 out of 214, k173=489
# Computing A^174 out of 214, k174=453
# Computing A^175 out of 214, k175=177
# Computing A^176 out of 214, k176=113
# Computing A^177 out of 214, k177=218
# Computing A^178 out of 214, k178=117
# Computing A^179 out of 214, k179=115
# Computing A^180 out of 214, k180=1024
# Computing A^181 out of 214, k181=61
# Computing A^182 out of 214, k182=365
# Computing A^183 out of 214, k183=323
# Computing A^184 out of 214, k184=852
# Computing A^185 out of 214, k185=349
# Computing A^186 out of 214, k186=337
# Computing A^187 out of 214, k187=378
# Computing A^188 out of 214, k188=167
# Computing A^189 out of 214, k189=253
# Computing A^190 out of 214, k190=217
# Computing A^191 out of 214, k191=595
# Computing A^192 out of 214, k192=237
# Computing A^193 out of 214, k193=185
# Computing A^194 out of 214, k194=87
# Computing A^195 out of 214, k195=130
# Computing A^196 out of 214, k196=31
# Computing A^197 out of 214, k197=61
# Computing A^198 out of 214, k198=409
# Computing A^199 out of 214, k199=2936
# Computing A^200 out of 214, k200=497
# Computing A^201 out of 214, k201=315
# Computing A^202 out of 214, k202=884
# Computing A^203 out of 214, k203=308
# Computing A^204 out of 214, k204=154
# Computing A^205 out of 214, k205=1552
# Computing A^206 out of 214, k206=219
# Computing A^207 out of 214, k207=608
# Computing A^208 out of 214, k208=97
# Computing A^209 out of 214, k209=88
# Computing A^210 out of 214, k210=144
# Computing A^211 out of 214, k211=423
# Computing A^212 out of 214, k212=172
# Computing A^213 out of 214, k213=3838
# Computing A^214 out of 214, k214=332

# %%
start = time.time()
lip = hpL2.opA.estimate_lipschitz(method='svd')
print("Computation time of the Lipschitz constant: {:.4f}".format(time.time()-start))
print("Lipschitz constant:", lip)
#np.linalg.svd to compute the largest singular value which is = to the lipschitz constant for linear operators
# Out:
# Computation time of the Lipschitz constant: 25.8925
# Lipschitz constant: 978.3462949963274

# %%
hpL2.plot_realization()

# %% [markdown]
# ### Define solver

# %%
# Parameter for reconstruction
#lambda_factor = 0.1

## Parameters of the solvers
# Base
remove = True
min_iterations = 1
# Stop
eps = 1e-4
tmax = 600.0
eps_dcv = 1e-2
# PFW
ms_threshold = 0.7  # original value 0.8, the lower the more atoms will HP select
init_correction = 1e-1
final_correction = 1e-6
correction_steps = 5

#lambda_ = lambda_factor * np.linalg.norm(op.T(measurements), np.infty)  # rule of thumb to define lambda
lambda_ = 1e1

# %%
pfw = pyfwl.PFWLasso(
    forwardOp=hpL2.opA,
    convexOp=hpL2.E,
    lambda_=lambda_,
    M=hpL2.M,
    negLogL=hpL2.negLogL,
    ms_threshold=ms_threshold,
    init_correction_prec=init_correction,
    final_correction_prec=final_correction,
    remove_positions=remove,
    min_correction_steps=correction_steps,
    show_progress=False,
)

# %%
stop_crit = pxos.RelError(
    eps=eps,
    var="objective_func",
    f=None,
    norm=2,
    satisfy_all=True,
)
# alternative stopping criteria
dcv = pyfwl.dcvStoppingCrit(eps_dcv)

# Minimum number of iterations
min_iter = pxos.MaxIter(n=min_iterations)

# Maximum duration
max_duration = pxos.MaxDuration(t=dt.timedelta(seconds=tmax))

stop = (min_iter & stop_crit) | max_duration

# track DCV
track_dcv = pxos.AbsError(eps=1e-10, var="dcv", f=None, norm=2, satisfy_all=True)

# %% [markdown]
# ### Solving

# %%
print("Polyatomic FW: Solving ...")
start = time.time()
pfw.fit(stop_crit= stop | track_dcv, diff_lipschitz=lip**2)
data_p, hist_p = pfw.stats()
time_p = time.time() - start
print("\tSolved in {:.3f} seconds".format(time_p))
# Out:
# Polyatomic FW: Solving ...
# diff_lipschitz constant provided.
# initial value: [-3233.06622152]
# new indices [  649   676   816  6454  6481  6621 36554 36581 36721 42769]
# actual new indices: 10
# new indices [  649   676   816  1945  6454  6481  6621  9874 36554 36581 36721 42574
#  42601 42769 42783 45584 45611 45751 45779 45793]
# actual new indices: 10
# new indices [  649   676   816  1945  4095  4331  4471  6454  6481  6621  9874  9921
#  19811 21886 24305 36554 36581 36721 42601 42769 42783 45584 45611 45751
#  45793]
# actual new indices: 7
# new indices [  649   676   816  1945  4331  4471  6454  6481  6621  9874  9921 16969
#  19811 19951 21886 25380 25390 25489 25569 36366 36506 36554 36581 36721
#  42769 45751]
# actual new indices: 8
# new indices [  649   676   816  1945  4331  4761  6454  6481  6621  9874  9921 21886
#  36581 36721]
# actual new indices: 1
# new indices [  649   676   816  1945  6454  6481  6621  7341  7481  9874  9921 21886
#  36581 36721 36964 38684 44059 44073]
# actual new indices: 6
# new indices [  649   676  4284  5789  6454  6481  6621  9874  9921 21241 21886 28336
#  36721]
# actual new indices: 4
# new indices [  649   676  6481  7696  9874 21886 36721 43414]
# actual new indices: 2
# new indices [  676  6481 21886 36721]
# actual new indices: 0
# new indices [  676  6481 21886 36721]
# actual new indices: 0
# new indices [  676  6481 10545 21886 33120 36721]
# actual new indices: 2
# new indices [ 6481 14819 21886 36721]
# actual new indices: 1
# new indices [ 4955  6481 10781 21886 25139 36721]
# actual new indices: 3
# new indices [ 6481 10975 11084 15651 21886 32584 35915 36721]
# actual new indices: 5
# new indices [ 6481 14415 14436 21886 24494 36721]
# actual new indices: 3
# new indices [ 6481 21886 25784 28390 36721]
# actual new indices: 2
# new indices [ 6481 14174 21295 21886 23251 25186 26443 36721]
# actual new indices: 5
# new indices [ 6481  7266  8341 21886 24111 36319 36333 36721 42365]
# actual new indices: 6
# new indices [ 6481 20220 21886 35485 36721 45181]
# actual new indices: 3
# new indices [ 6481 21886 33309 36721]
# actual new indices: 1
# new indices [ 2181  6481 21886 36721]
# actual new indices: 1
# new indices [ 6481 21886 34410 36721 41049 44489]
# actual new indices: 3
# new indices [ 6481 21886 26644 36721 39785 43440]
# actual new indices: 3
# new indices [ 3450  6481 12884 21886 36721]
# actual new indices: 2
# new indices [ 4686  6481 21886 23896 36721]
# actual new indices: 2
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721 39376]
# actual new indices: 1
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 21886 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [ 6481 36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# new indices [36721]
# actual new indices: 0
# 	Solved in 600.206 seconds

# %% [markdown]
# ### Evaluation of the solve

# %%
print("Final value of dual certificate:\n\tPFW: {:.4f}".format(data_p["dcv"]))
print("Final value of objective function:\n\tPFW : {:.2f}".format(hist_p[-1][-1]))
# Out:
# Final value of dual certificate:
# 	PFW: 52.5247
# Final value of objective function:
# 	PFW : -1388157.30

# %%
def supp(arr):
    return np.where(np.abs(arr) > 1e-3)[0]
M = hpL2.M

#print(data_p["x"][supp(data_p["x"])])
#print(data_p["x"])
# for i in range(M):
#     print(f"Process {i}:", data_p["x"][(i*(M + 1)):(i*(M + 1) + M + 1)])

# Arrange intensities in a M x M matrix
intensities = np.zeros((M, M))
for i in range(M):
    intensities[i, :] = data_p["x"][(i*(M + 1) + 1):(i*(M + 1) + M + 1)]

# %%
# Visualize solution
fig, ax = plt.subplots(1, 1, figsize=(5,5))
im = ax.imshow(intensities/(beta*beta), # la norme L1 est alpha/beta^2
                cmap='viridis', 
                interpolation='nearest', 
                extent=[1, M, M, 1])
fig.colorbar(im, ax=ax)  # Add a colorbar to show the scale
ax.set_title('L1 norms of the $h_{ij}$')
plt.show()

for i in range(M):
    print(f"mu{i+1}:", data_p["x"][i*(M + 1)])

